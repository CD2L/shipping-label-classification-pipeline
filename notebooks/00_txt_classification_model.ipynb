# %% [markdown]
# # Classfication of address tags
# In this notebook, we will try de classify address tags containing a keyword which will allow the AI to decides wether or not this address is the sender address.
#
# Input data:
# Data is generated with the file "text-classification-generator.py". It uses a list of 1849 european addresses, 38 different keywords to identify senders and 32 keywords to identify receivers. With these lists, it creates a new file named "generated.csv" composed with :
# - a label : "sender_details" or "receiver_details"
# - an address : text representing an address, with a keyword included in the address line in a random position
# - a width : width of the bloc detected by the object detection AI
# - a height : height of the bloc detected by the object detection AI

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import multilabel_confusion_matrix, classification_report
import string
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model
from matplotlib import pyplot as plt
import pickle

# %%
df = pd.read_csv('../utils/generated.csv', sep=';', encoding='utf-8')

# %%
def plot_scores(train) :
    accuracy = train.history['accuracy']
    val_accuracy = train.history['val_accuracy']
    epochs = range(len(accuracy))
    plt.plot(epochs, accuracy, 'b', label='Score apprentissage')
    plt.plot(epochs, val_accuracy, 'r', label='Score validation')
    plt.title('Scores')
    plt.legend()
    plt.show()

# %%
def plot_scores_siamois(train) :
    accuracy_1 = train.history['output_addr_1_accuracy']
    accuracy_2 = train.history['output_addr_2_accuracy']
    
    val_accuracy_1 = train.history['val_output_addr_1_accuracy']
    val_accuracy_2 = train.history['val_output_addr_2_accuracy']
    
    epochs = range(len(accuracy_1))
    plt.plot(epochs, accuracy_1, 'b', label='Score apprentissage output 1')
    plt.plot(epochs, accuracy_2, 'darkblue', label='Score apprentissage output 2')
    plt.plot(epochs, val_accuracy_1, 'r', label='Score validation output 1')
    plt.plot(epochs, val_accuracy_2, 'darkred', label='Score validation output 2')
    plt.title('Scores')
    plt.legend()
    plt.show()

# %% [markdown]
# ## Preprocessing

# %%
X = df.drop(["label", "width", "height"], 1)
y = df.label
# Out:
# C:\Users\sacha\AppData\Local\Temp\ipykernel_1264\2548596853.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = df.drop(["label", "width", "height"], 1)

# %%
translator = str.maketrans(string.punctuation, ' '*len(string.punctuation))

# %%
X.text[0]
# Out:
# ' 11 Belmont Road'

# %%
new_X = []
for i, sentence in enumerate(X.text):
    tmp_sentence = sentence.lower()
    tmp_sentence = tmp_sentence.replace('\n', '')
    tmp_sentence = tmp_sentence.translate(translator)
    new_X.append(tmp_sentence)

# %%
new_X[0]
# Out:
# ' 11 belmont road'

# %%
X = new_X

# %%
top_words = 20000
tokenizer = Tokenizer(num_words=top_words, char_level=True)
tokenizer.fit_on_texts(X)
X = tokenizer.texts_to_sequences(X)

with open('../models/tokenizer_clf.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
np.max([len(i) for i in X])
# Out:
# 130

# %%
max_words = 200
X = sequence.pad_sequences(X, maxlen=max_words, padding='post')

# %%
y = y.map({'sender_details': 0, 'receiver_details': 1, 'unknown': 2})
y = to_categorical(y)

# %%
X = X.reshape(int(X.shape[0]/2),2,X.shape[1])
y = y.reshape(int(y.shape[0]/2),2,y.shape[1])

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.25)

# %%
X_train.shape
# Out:
# (1500, 2, 200)

# %%
X_train_A = np.array([X_train[i][0] for i in range(len(X_train))])
X_train_B = np.array([X_train[i][1] for i in range(len(X_train))])
X_test_A = np.array([X_test[i][0] for i in range(len(X_test))])
X_test_B = np.array([X_test[i][1] for i in range(len(X_test))])

y_train_A = np.array([y_train[i][0] for i in range(len(y_train))])
y_train_B = np.array([y_train[i][1] for i in range(len(y_train))])
y_test_A = np.array([y_test[i][0] for i in range(len(y_test))])
y_test_B = np.array([y_test[i][1] for i in range(len(y_test))])

# %%
def preprocessing(X,y = None,max_words = 200):
    with open('../models/tokenizer_clf.pickle', 'rb') as handle:
        tokenizer = pickle.load(handle)
    translator = str.maketrans(string.punctuation, ' '*len(string.punctuation))
    
    X_ = []
    for i, sentence in enumerate(X):
        tmp_sentence = sentence.lower()
        tmp_sentence = tmp_sentence.replace('\n', '')
        tmp_sentence = tmp_sentence.translate(translator)
        X_.append(tmp_sentence)
    X = X_.copy()
    
    X = tokenizer.texts_to_sequences(X)
    X = sequence.pad_sequences(X, maxlen=max_words, padding='post')

    X = X.reshape(int(X.shape[0]/2),2,X.shape[1])
    
    if y is not None:
        y = y.map({'sender_details': 0, 'receiver_details': 1, 'unknown': 2})
        y = to_categorical(y)
        y = y.reshape(int(y.shape[0]/2),2,y.shape[1])
        return X,y
    else :
        return X

# %%
def a_b_split(X,y):
    X_a = np.array([X[i][0] for i in range(len(X))])
    X_b = np.array([X[i][1] for i in range(len(X))])
    
    y_a = np.array([y[i][0] for i in range(len(y))])
    y_b = np.array([y[i][1] for i in range(len(y))])
    
    return X_a, X_b, y_a, y_b

# %% [markdown]
# ## Training
# ### CNN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding, Conv1D, MaxPool1D, Flatten, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.callbacks import EarlyStopping

# %%
X_train_B.shape
# Out:
# (1500, 200)

# %%
addr_1_input = Input(shape=(200,), name='input_addr_1')
txt_embed_1 = Embedding(3750,200,input_length=200)(addr_1_input)

addr_2_input = Input(shape=(200,), name='input_addr_2')
txt_embed_2 = Embedding(3750,200,input_length=200)(addr_2_input)

conv_1_1 = Conv1D(128,5, activation='relu')(txt_embed_1)
drop_1_1 = Dropout(0.3)(conv_1_1)
maxpool_1_1 = MaxPool1D()(drop_1_1)
conv_1_2 = Conv1D(64,3, activation='relu')(maxpool_1_1)
drop_1_5 = Dropout(0.5)(conv_1_2)
maxpool_1_5 = MaxPool1D()(drop_1_5)
conv_1_3 = Conv1D(32,3, activation='relu')(maxpool_1_5)
drop_1_2 = Dropout(0.5)(conv_1_3)
maxpool_1_2 = MaxPool1D()(drop_1_2)
conv_1_4 = Conv1D(16,3, activation='relu')(maxpool_1_2)

conv_2_1 = Conv1D(128,5, activation='relu')(txt_embed_2)
drop_2_1 = Dropout(0.3)(conv_2_1)
maxpool_2_1 = MaxPool1D()(drop_2_1)
conv_2_2 = Conv1D(64,3, activation='relu')(maxpool_2_1)
drop_2_5 = Dropout(0.5)(conv_2_2)
maxpool_2_5 = MaxPool1D()(drop_2_5)
conv_2_3 = Conv1D(32,3, activation='relu')(maxpool_2_5)
drop_2_2 = Dropout(0.5)(conv_2_3)
maxpool_2_2 = MaxPool1D()(drop_2_2)
conv_2_4 = Conv1D(16,3, activation='relu')(maxpool_2_2)

concat = Concatenate()([conv_1_4, conv_2_4])
flatten = Flatten()(concat)

dense_1 = Dense(3, activation='softmax', name='output_addr_1')(flatten)
dense_2 = Dense(3, activation='softmax', name='output_addr_2')(flatten)

model = Model([addr_1_input, addr_2_input], [dense_1, dense_2])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
len(X_train_B)
# Out:
# 1500

# %%
plot_model(model, show_shapes=True)

# %%
es = EarlyStopping("val_output_addr_1_accuracy", 0.001, 100, mode='max', restore_best_weights=True)

train = model.fit(
    {'input_addr_1': X_train_A, 'input_addr_2': X_train_B},
    {'output_addr_1': y_train_A, 'output_addr_2': y_train_B}, 
    validation_data=(
        {'input_addr_1': X_test_A, 'input_addr_2': X_test_B},
        {'output_addr_1': y_test_A, 'output_addr_2': y_test_B}), 
    epochs=1000, batch_size=256, callbacks=[es], verbose=2)
# Out:
# Epoch 1/1000
# 6/6 - 5s - loss: 2.2005 - output_addr_1_loss: 1.1001 - output_addr_2_loss: 1.1005 - output_addr_1_accuracy: 0.3493 - output_addr_2_accuracy: 0.3360 - val_loss: 2.1957 - val_output_addr_1_loss: 1.0980 - val_output_addr_2_loss: 1.0978 - val_output_addr_1_accuracy: 0.3480 - val_output_addr_2_accuracy: 0.3800 - 5s/epoch - 774ms/step
# Epoch 2/1000
# 6/6 - 0s - loss: 2.1936 - output_addr_1_loss: 1.0969 - output_addr_2_loss: 1.0967 - output_addr_1_accuracy: 0.3520 - output_addr_2_accuracy: 0.3740 - val_loss: 2.1961 - val_output_addr_1_loss: 1.0988 - val_output_addr_2_loss: 1.0973 - val_output_addr_1_accuracy: 0.3360 - val_output_addr_2_accuracy: 0.3740 - 363ms/epoch - 61ms/step
# Epoch 3/1000
# 6/6 - 0s - loss: 2.1894 - output_addr_1_loss: 1.0959 - output_addr_2_loss: 1.0935 - output_addr_1_accuracy: 0.3800 - output_addr_2_accuracy: 0.3700 - val_loss: 2.1921 - val_output_addr_1_loss: 1.0969 - val_output_addr_2_loss: 1.0952 - val_output_addr_1_accuracy: 0.3600 - val_output_addr_2_accuracy: 0.3920 - 377ms/epoch - 63ms/step
# Epoch 4/1000
# 6/6 - 0s - loss: 2.1767 - output_addr_1_loss: 1.0909 - output_addr_2_loss: 1.0858 - output_addr_1_accuracy: 0.3820 - output_addr_2_accuracy: 0.4007 - val_loss: 2.1892 - val_output_addr_1_loss: 1.0963 - val_output_addr_2_loss: 1.0929 - val_output_addr_1_accuracy: 0.3900 - val_output_addr_2_accuracy: 0.3920 - 352ms/epoch - 59ms/step
# Epoch 5/1000
# 6/6 - 0s - loss: 2.1674 - output_addr_1_loss: 1.0863 - output_addr_2_loss: 1.0811 - output_addr_1_accuracy: 0.3900 - output_addr_2_accuracy: 0.4067 - val_loss: 2.1822 - val_output_addr_1_loss: 1.0955 - val_output_addr_2_loss: 1.0867 - val_output_addr_1_accuracy: 0.3920 - val_output_addr_2_accuracy: 0.4560 - 345ms/epoch - 57ms/step
# Epoch 136/1000
# 6/6 - 0s - loss: 0.0216 - output_addr_1_loss: 0.0130 - output_addr_2_loss: 0.0087 - output_addr_1_accuracy: 0.9947 - output_addr_2_accuracy: 0.9987 - val_loss: 1.0662 - val_output_addr_1_loss: 0.4444 - val_output_addr_2_loss: 0.6219 - val_output_addr_1_accuracy: 0.8520 - val_output_addr_2_accuracy: 0.8460 - 342ms/epoch - 57ms/step
# Epoch 137/1000
# 6/6 - 0s - loss: 0.0239 - output_addr_1_loss: 0.0112 - output_addr_2_loss: 0.0127 - output_addr_1_accuracy: 0.9980 - output_addr_2_accuracy: 0.9960 - val_loss: 1.0590 - val_output_addr_1_loss: 0.4434 - val_output_addr_2_loss: 0.6156 - val_output_addr_1_accuracy: 0.8460 - val_output_addr_2_accuracy: 0.8320 - 332ms/epoch - 55ms/step
# Epoch 138/1000
# 6/6 - 0s - loss: 0.0188 - output_addr_1_loss: 0.0117 - output_addr_2_loss: 0.0071 - output_addr_1_accuracy: 0.9967 - output_addr_2_accuracy: 0.9973 - val_loss: 1.1519 - val_output_addr_1_loss: 0.4655 - val_output_addr_2_loss: 0.6864 - val_output_addr_1_accuracy: 0.8420 - val_output_addr_2_accuracy: 0.8200 - 305ms/epoch - 51ms/step
# Epoch 139/1000
# ...
# Epoch 735/1000
# 6/6 - 0s - loss: 0.0031 - output_addr_1_loss: 0.0029 - output_addr_2_loss: 1.7678e-04 - output_addr_1_accuracy: 0.9987 - output_addr_2_accuracy: 1.0000 - val_loss: 0.6732 - val_output_addr_1_loss: 0.2857 - val_output_addr_2_loss: 0.3875 - val_output_addr_1_accuracy: 0.9260 - val_output_addr_2_accuracy: 0.9640 - 348ms/epoch - 58ms/step
# Epoch 736/1000
# 6/6 - 0s - loss: 0.0011 - output_addr_1_loss: 6.1675e-04 - output_addr_2_loss: 5.0219e-04 - output_addr_1_accuracy: 1.0000 - output_addr_2_accuracy: 1.0000 - val_loss: 0.6931 - val_output_addr_1_loss: 0.2872 - val_output_addr_2_loss: 0.4059 - val_output_addr_1_accuracy: 0.9280 - val_output_addr_2_accuracy: 0.9640 - 332ms/epoch - 55ms/step
# Epoch 737/1000
# 6/6 - 0s - loss: 0.0016 - output_addr_1_loss: 0.0012 - output_addr_2_loss: 3.5339e-04 - output_addr_1_accuracy: 0.9993 - output_addr_2_accuracy: 1.0000 - val_loss: 0.7164 - val_output_addr_1_loss: 0.2682 - val_output_addr_2_loss: 0.4482 - val_output_addr_1_accuracy: 0.9320 - val_output_addr_2_accuracy: 0.9580 - 332ms/epoch - 55ms/step
# Epoch 738/1000
# 6/6 - 0s - loss: 6.7307e-04 - output_addr_1_loss: 1.8787e-04 - output_addr_2_loss: 4.8520e-04 - output_addr_1_accuracy: 1.0000 - output_addr_2_accuracy: 1.0000 - val_loss: 0.6902 - val_output_addr_1_loss: 0.2762 - val_output_addr_2_loss: 0.4141 - val_output_addr_1_accuracy: 0.9300 - val_output_addr_2_accuracy: 0.9660 - 317ms/epoch - 53ms/step
# Epoch 739/1000
# 6/6 - 0s - loss: 3.6194e-04 - output_addr_1_loss: 2.9871e-04 - output_addr_2_loss: 6.3225e-05 - output_addr_1_accuracy: 1.0000 - output_addr_2_accuracy: 1.0000 - val_loss: 0.6635 - val_output_addr_1_loss: 0.2533 - val_output_addr_2_loss: 0.4101 - val_output_addr_1_accuracy: 0.9300 - val_output_addr_2_accuracy: 0.9640 - 343ms/epoch - 57ms/step
# Epoch 740/1000
# 6/6 - 0s - loss: 0.0039 - output_addr_1_loss: 0.0038 - output_addr_2_loss: 1.3798e-04 - output_addr_1_accuracy: 0.9993 - output_addr_2_accuracy: 1.0000 - val_loss: 0.6583 - val_output_addr_1_loss: 0.2489 - val_output_addr_2_loss: 0.4093 - val_output_addr_1_accuracy: 0.9340 - val_output_addr_2_accuracy: 0.9680 - 347ms/epoch - 58ms/step
# Epoch 741/1000
# 6/6 - 0s - loss: 0.0018 - output_addr_1_loss: 0.0014 - output_addr_2_loss: 4.2564e-04 - output_addr_1_accuracy: 0.9993 - output_addr_2_accuracy: 1.0000 - val_loss: 0.7719 - val_output_addr_1_loss: 0.4028 - val_output_addr_2_loss: 0.3691 - val_output_addr_1_accuracy: 0.9020 - val_output_addr_2_accuracy: 0.9640 - 328ms/epoch - 55ms/step
# Epoch 742/1000
# 6/6 - 0s - loss: 0.0036 - output_addr_1_loss: 0.0035 - output_addr_2_loss: 1.2324e-04 - output_addr_1_accuracy: 0.9980 - output_addr_2_accuracy: 1.0000 - val_loss: 0.6236 - val_output_addr_1_loss: 0.2389 - val_output_addr_2_loss: 0.3847 - val_output_addr_1_accuracy: 0.9400 - val_output_addr_2_accuracy: 0.9680 - 317ms/epoch - 53ms/step
# Epoch 743/1000
# 6/6 - 0s - loss: 3.1978e-04 - output_addr_1_loss: 2.2096e-04 - output_addr_2_loss: 9.8817e-05 - output_addr_1_accuracy: 1.0000 - output_addr_2_accuracy: 1.0000 - val_loss: 0.6042 - val_output_addr_1_loss: 0.1989 - val_output_addr_2_loss: 0.4053 - val_output_addr_1_accuracy: 0.9540 - val_output_addr_2_accuracy: 0.9660 - 315ms/epoch - 52ms/step
# Epoch 744/1000
# 6/6 - 0s - loss: 0.0021 - output_addr_1_loss: 0.0018 - output_addr_2_loss: 2.2868e-04 - output_addr_1_accuracy: 0.9987 - output_addr_2_accuracy: 1.0000 - val_loss: 0.5740 - val_output_addr_1_loss: 0.1857 - val_output_addr_2_loss: 0.3883 - val_output_addr_1_accuracy: 0.9520 - val_output_addr_2_accuracy: 0.9680 - 309ms/epoch - 52ms/step
# Epoch 745/1000
# 6/6 - 0s - loss: 6.8227e-04 - output_addr_1_loss: 6.0571e-04 - output_addr_2_loss: 7.6557e-05 - output_addr_1_accuracy: 0.9993 - output_addr_2_accuracy: 1.0000 - val_loss: 0.6027 - val_output_addr_1_loss: 0.2432 - val_output_addr_2_loss: 0.3595 - val_output_addr_1_accuracy: 0.9380 - val_output_addr_2_accuracy: 0.9700 - 319ms/epoch - 53ms/step
# Epoch 746/1000
# 6/6 - 0s - loss: 0.0025 - output_addr_1_loss: 2.1813e-04 - output_addr_2_loss: 0.0023 - output_addr_1_accuracy: 1.0000 - output_addr_2_accuracy: 0.9993 - val_loss: 0.7014 - val_output_addr_1_loss: 0.1969 - val_output_addr_2_loss: 0.5045 - val_output_addr_1_accuracy: 0.9440 - val_output_addr_2_accuracy: 0.9540 - 327ms/epoch - 55ms/step
# Epoch 747/1000
# 6/6 - 0s - loss: 0.0077 - output_addr_1_loss: 0.0025 - output_addr_2_loss: 0.0052 - output_addr_1_accuracy: 0.9987 - output_addr_2_accuracy: 0.9987 - val_loss: 0.5774 - val_output_addr_1_loss: 0.2111 - val_output_addr_2_loss: 0.3663 - val_output_addr_1_accuracy: 0.9380 - val_output_addr_2_accuracy: 0.9700 - 348ms/epoch - 58ms/step
# Epoch 748/1000
# 6/6 - 0s - loss: 0.0055 - output_addr_1_loss: 0.0016 - output_addr_2_loss: 0.0038 - output_addr_1_accuracy: 0.9993 - output_addr_2_accuracy: 0.9987 - val_loss: 0.5934 - val_output_addr_1_loss: 0.1701 - val_output_addr_2_loss: 0.4233 - val_output_addr_1_accuracy: 0.9560 - val_output_addr_2_accuracy: 0.9640 - 317ms/epoch - 53ms/step
# Epoch 749/1000
# 6/6 - 0s - loss: 0.0026 - output_addr_1_loss: 0.0025 - output_addr_2_loss: 1.3856e-04 - output_addr_1_accuracy: 0.9993 - output_addr_2_accuracy: 1.0000 - val_loss: 0.6693 - val_output_addr_1_loss: 0.2303 - val_output_addr_2_loss: 0.4389 - val_output_addr_1_accuracy: 0.9360 - val_output_addr_2_accuracy: 0.9660 - 318ms/epoch - 53ms/step
# Epoch 750/1000
# 6/6 - 0s - loss: 0.0037 - output_addr_1_loss: 0.0022 - output_addr_2_loss: 0.0015 - output_addr_1_accuracy: 0.9993 - output_addr_2_accuracy: 0.9993 - val_loss: 0.7157 - val_output_addr_1_loss: 0.2854 - val_output_addr_2_loss: 0.4303 - val_output_addr_1_accuracy: 0.9240 - val_output_addr_2_accuracy: 0.9620 - 314ms/epoch - 52ms/step
# Epoch 751/1000
# 6/6 - 0s - loss: 0.0029 - output_addr_1_loss: 0.0027 - output_addr_2_loss: 1.8481e-04 - output_addr_1_accuracy: 0.9993 - output_addr_2_accuracy: 1.0000 - val_loss: 0.7792 - val_output_addr_1_loss: 0.3477 - val_output_addr_2_loss: 0.4315 - val_output_addr_1_accuracy: 0.9160 - val_output_addr_2_accuracy: 0.9620 - 326ms/epoch - 54ms/step
# Epoch 752/1000
# 6/6 - 0s - loss: 0.0026 - output_addr_1_loss: 0.0025 - output_addr_2_loss: 9.5143e-05 - output_addr_1_accuracy: 0.9993 - output_addr_2_accuracy: 1.0000 - val_loss: 0.7036 - val_output_addr_1_loss: 0.2514 - val_output_addr_2_loss: 0.4522 - val_output_addr_1_accuracy: 0.9380 - val_output_addr_2_accuracy: 0.9580 - 318ms/epoch - 53ms/step
# Epoch 753/1000
# 6/6 - 0s - loss: 0.0016 - output_addr_1_loss: 2.6344e-04 - output_addr_2_loss: 0.0013 - output_addr_1_accuracy: 1.0000 - output_addr_2_accuracy: 0.9993 - val_loss: 0.7449 - val_output_addr_1_loss: 0.2030 - val_output_addr_2_loss: 0.5419 - val_output_addr_1_accuracy: 0.9640 - val_output_addr_2_accuracy: 0.9480 - 322ms/epoch - 54ms/step
# Epoch 754/1000
# 6/6 - 0s - loss: 0.0031 - output_addr_1_loss: 0.0014 - output_addr_2_loss: 0.0017 - output_addr_1_accuracy: 0.9993 - output_addr_2_accuracy: 0.9993 - val_loss: 0.5673 - val_output_addr_1_loss: 0.1666 - val_output_addr_2_loss: 0.4007 - val_output_addr_1_accuracy: 0.9640 - val_output_addr_2_accuracy: 0.9620 - 408ms/epoch - 68ms/step
# Epoch 755/1000
# 6/6 - 0s - loss: 0.0052 - output_addr_1_loss: 0.0051 - output_addr_2_loss: 1.7295e-04 - output_addr_1_accuracy: 0.9973 - output_addr_2_accuracy: 1.0000 - val_loss: 0.5871 - val_output_addr_1_loss: 0.2371 - val_output_addr_2_loss: 0.3500 - val_output_addr_1_accuracy: 0.9320 - val_output_addr_2_accuracy: 0.9520 - 318ms/epoch - 53ms/step
# Epoch 756/1000
# 6/6 - 0s - loss: 0.0079 - output_addr_1_loss: 4.2301e-04 - output_addr_2_loss: 0.0075 - output_addr_1_accuracy: 1.0000 - output_addr_2_accuracy: 0.9987 - val_loss: 0.5608 - val_output_addr_1_loss: 0.1720 - val_output_addr_2_loss: 0.3888 - val_output_addr_1_accuracy: 0.9600 - val_output_addr_2_accuracy: 0.9600 - 334ms/epoch - 56ms/step
# Epoch 757/1000
# 6/6 - 0s - loss: 0.0069 - output_addr_1_loss: 0.0019 - output_addr_2_loss: 0.0050 - output_addr_1_accuracy: 0.9987 - output_addr_2_accuracy: 0.9987 - val_loss: 0.5486 - val_output_addr_1_loss: 0.1980 - val_output_addr_2_loss: 0.3506 - val_output_addr_1_accuracy: 0.9580 - val_output_addr_2_accuracy: 0.9660 - 313ms/epoch - 52ms/step
# Epoch 758/1000
# 6/6 - 0s - loss: 0.0016 - output_addr_1_loss: 9.7334e-04 - output_addr_2_loss: 6.3875e-04 - output_addr_1_accuracy: 1.0000 - output_addr_2_accuracy: 1.0000 - val_loss: 0.5997 - val_output_addr_1_loss: 0.2670 - val_output_addr_2_loss: 0.3327 - val_output_addr_1_accuracy: 0.9440 - val_output_addr_2_accuracy: 0.9640 - 319ms/epoch - 53ms/step
# Epoch 759/1000
# 6/6 - 0s - loss: 0.0188 - output_addr_1_loss: 5.4950e-04 - output_addr_2_loss: 0.0182 - output_addr_1_accuracy: 1.0000 - output_addr_2_accuracy: 0.9947 - val_loss: 0.6441 - val_output_addr_1_loss: 0.1725 - val_output_addr_2_loss: 0.4716 - val_output_addr_1_accuracy: 0.9660 - val_output_addr_2_accuracy: 0.9560 - 327ms/epoch - 55ms/step
# Epoch 760/1000
# 6/6 - 0s - loss: 0.0068 - output_addr_1_loss: 1.7961e-04 - output_addr_2_loss: 0.0067 - output_addr_1_accuracy: 1.0000 - output_addr_2_accuracy: 0.9980 - val_loss: 0.5594 - val_output_addr_1_loss: 0.1587 - val_output_addr_2_loss: 0.4006 - val_output_addr_1_accuracy: 0.9700 - val_output_addr_2_accuracy: 0.9620 - 348ms/epoch - 58ms/step
# Epoch 761/1000
# 6/6 - 0s - loss: 0.0043 - output_addr_1_loss: 2.5210e-04 - output_addr_2_loss: 0.0040 - output_addr_1_accuracy: 1.0000 - output_addr_2_accuracy: 0.9987 - val_loss: 0.5526 - val_output_addr_1_loss: 0.1594 - val_output_addr_2_loss: 0.3932 - val_output_addr_1_accuracy: 0.9680 - val_output_addr_2_accuracy: 0.9680 - 320ms/epoch - 53ms/step
# Epoch 762/1000
# 6/6 - 0s - loss: 0.0126 - output_addr_1_loss: 0.0019 - output_addr_2_loss: 0.0107 - output_addr_1_accuracy: 0.9987 - output_addr_2_accuracy: 0.9980 - val_loss: 0.5675 - val_output_addr_1_loss: 0.1457 - val_output_addr_2_loss: 0.4218 - val_output_addr_1_accuracy: 0.9680 - val_output_addr_2_accuracy: 0.9620 - 324ms/epoch - 54ms/step
# Epoch 763/1000
# 6/6 - 0s - loss: 0.0014 - output_addr_1_loss: 4.8360e-04 - output_addr_2_loss: 8.8915e-04 - output_addr_1_accuracy: 1.0000 - output_addr_2_accuracy: 1.0000 - val_loss: 0.5374 - val_output_addr_1_loss: 0.1576 - val_output_addr_2_loss: 0.3798 - val_output_addr_1_accuracy: 0.9640 - val_output_addr_2_accuracy: 0.9560 - 328ms/epoch - 55ms/step
# Epoch 764/1000
# 6/6 - 0s - loss: 0.0080 - output_addr_1_loss: 2.5659e-04 - output_addr_2_loss: 0.0077 - output_addr_1_accuracy: 1.0000 - output_addr_2_accuracy: 0.9967 - val_loss: 0.5546 - val_output_addr_1_loss: 0.1819 - val_output_addr_2_loss: 0.3727 - val_output_addr_1_accuracy: 0.9520 - val_output_addr_2_accuracy: 0.9600 - 339ms/epoch - 56ms/step
# Epoch 765/1000
# 6/6 - 0s - loss: 0.0056 - output_addr_1_loss: 0.0017 - output_addr_2_loss: 0.0040 - output_addr_1_accuracy: 0.9993 - output_addr_2_accuracy: 0.9993 - val_loss: 0.6643 - val_output_addr_1_loss: 0.1554 - val_output_addr_2_loss: 0.5089 - val_output_addr_1_accuracy: 0.9640 - val_output_addr_2_accuracy: 0.9520 - 323ms/epoch - 54ms/step
# Epoch 766/1000
# 6/6 - 0s - loss: 0.0176 - output_addr_1_loss: 0.0014 - output_addr_2_loss: 0.0162 - output_addr_1_accuracy: 0.9993 - output_addr_2_accuracy: 0.9967 - val_loss: 0.5293 - val_output_addr_1_loss: 0.1595 - val_output_addr_2_loss: 0.3697 - val_output_addr_1_accuracy: 0.9620 - val_output_addr_2_accuracy: 0.9640 - 325ms/epoch - 54ms/step
# Epoch 767/1000
# 6/6 - 0s - loss: 0.0168 - output_addr_1_loss: 0.0049 - output_addr_2_loss: 0.0119 - output_addr_1_accuracy: 0.9993 - output_addr_2_accuracy: 0.9973 - val_loss: 0.6514 - val_output_addr_1_loss: 0.3237 - val_output_addr_2_loss: 0.3277 - val_output_addr_1_accuracy: 0.9360 - val_output_addr_2_accuracy: 0.9540 - 315ms/epoch - 53ms/step
# Epoch 768/1000
# 6/6 - 0s - loss: 0.0155 - output_addr_1_loss: 0.0011 - output_addr_2_loss: 0.0144 - output_addr_1_accuracy: 1.0000 - output_addr_2_accuracy: 0.9947 - val_loss: 0.5515 - val_output_addr_1_loss: 0.1424 - val_output_addr_2_loss: 0.4091 - val_output_addr_1_accuracy: 0.9600 - val_output_addr_2_accuracy: 0.9560 - 313ms/epoch - 52ms/step
# Epoch 769/1000
# 6/6 - 0s - loss: 0.0328 - output_addr_1_loss: 0.0201 - output_addr_2_loss: 0.0126 - output_addr_1_accuracy: 0.9993 - output_addr_2_accuracy: 0.9967 - val_loss: 0.5223 - val_output_addr_1_loss: 0.2534 - val_output_addr_2_loss: 0.2690 - val_output_addr_1_accuracy: 0.9460 - val_output_addr_2_accuracy: 0.9660 - 357ms/epoch - 59ms/step
# Epoch 770/1000
# 6/6 - 0s - loss: 0.0195 - output_addr_1_loss: 0.0122 - output_addr_2_loss: 0.0074 - output_addr_1_accuracy: 0.9973 - output_addr_2_accuracy: 0.9973 - val_loss: 0.4485 - val_output_addr_1_loss: 0.1343 - val_output_addr_2_loss: 0.3142 - val_output_addr_1_accuracy: 0.9600 - val_output_addr_2_accuracy: 0.9660 - 310ms/epoch - 52ms/step
# Epoch 771/1000
# 6/6 - 0s - loss: 0.0265 - output_addr_1_loss: 0.0158 - output_addr_2_loss: 0.0108 - output_addr_1_accuracy: 0.9960 - output_addr_2_accuracy: 0.9973 - val_loss: 0.5042 - val_output_addr_1_loss: 0.2321 - val_output_addr_2_loss: 0.2721 - val_output_addr_1_accuracy: 0.9420 - val_output_addr_2_accuracy: 0.9660 - 309ms/epoch - 51ms/step
# Epoch 779/1000
# 6/6 - 0s - loss: 0.0278 - output_addr_1_loss: 0.0172 - output_addr_2_loss: 0.0105 - output_addr_1_accuracy: 0.9960 - output_addr_2_accuracy: 0.9973 - val_loss: 0.3982 - val_output_addr_1_loss: 0.1614 - val_output_addr_2_loss: 0.2368 - val_output_addr_1_accuracy: 0.9600 - val_output_addr_2_accuracy: 0.9640 - 325ms/epoch - 54ms/step

# %%
plot_scores_siamois(train)

# %%
model.save('./models/1_addr_clf.h5')

# %%
X_test_A.shape

# %%
y_pred = model.predict({'input_addr_1' : X_test_A, 'input_addr_2': X_test_B})

# %%
y_pred_0 = (y_pred[0] > 0.5).astype(int)
y_pred_1 = (y_pred[1] > 0.5).astype(int)

# %%
print(multilabel_confusion_matrix(y_test_A, y_pred_0))
print(classification_report(y_test_A,y_pred_0))

# %%
print(multilabel_confusion_matrix(y_test_B, y_pred_1))
print(classification_report(y_test_B,y_pred_1))

# %% [markdown]
# ## Test with custom data

# %%
df_test = pd.read_csv('./generated-data/generated-t.csv', ';')

X = df_test.text
y = df_test.label

X,y = preprocessing(X,y)
X_a, X_b, y_a, y_b = a_b_split(X,y)

# %%
y_cnn = model.predict({'input_addr_1' : X_a, 'input_addr_2': X_b})

# %%
(y_cnn[0]>0.8).astype(int) - y_a.astype(int)

# %%
(y_cnn[1]>0.8).astype(int) - y_b.astype(int)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# As the classification AI works very well with keywords (like a regexp-based algorithm), it can happens that no key words has been found with the OCR AI or with the bloc detection AI. We must take in account that only 4 or 5 blocs will be detected, and so, in a new version, this program will have to classifies multiple classes and concludes which one is the sender and which one is the receiver. It could be interesting to create a new AI to classify wether the block is an address block or not. After this, we'll have to deal with only to blocs : the **sender** and the **receiver** ones. At this point, we could predict the class of just one block and then conclude that the second is the non found class.

# %% [markdown]
# ## In real situation

# %% [markdown]
# With real data

# %%
blocks_with_addresses = [
    "Service courrier GeoPost 9 rue Maurice from Mallet 92130 Issy Les Moulineaux ",
    "Perfect Barcode Ltd 123 Straightandnarrow Street Smethwick West midlands B66 1 BY CB England"
]

blocks_with_addresses = preprocessing(blocks_with_addresses)[0]
addr_a, addr_b = np.array(blocks_with_addresses[0]), np.array(blocks_with_addresses[1])

addr_a = addr_a.reshape(1,200)
addr_b = addr_b.reshape(1,200)

pred = model.predict({'input_addr_1' : addr_a, 'input_addr_2': addr_b})

classes = ['sender', 'receiver', 'unknown']

print(classes[np.argmax(pred[0])], pred[0][0][np.argmax(pred[0])], pred[0][0])
print(classes[np.argmax(pred[1])], pred[1][0][np.argmax(pred[1])], pred[1][0])
# Out:
# 1/1 [==============================] - 0s 39ms/step
# sender 0.6174636 [0.6174636  0.05010425 0.33243215]
# sender 0.9889319 [9.8893189e-01 1.1044186e-02 2.3970204e-05]
